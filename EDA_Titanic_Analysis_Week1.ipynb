# %% [markdown]
# <a href="https://colab.research.google.com/github/Piyush1803/EDA-Titanic-Analysis/blob/main/EDA_Titanic_Analysis_Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn

# %% [markdown]
# To Upload file on GoogleColab

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d95d7582-9731-4189-961b-8dda1e1bf187" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d95d7582-9731-4189-961b-8dda1e1bf187">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# To Save It to Correct Location and permission

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Install Kaggle CLI

# %%
# !pip install kaggle

# %% [markdown]
# Verify Authentication
#
# *   If it prints a list of datasets, you’re successfully connected

# %%
# !kaggle datasets list | head
# Out:
# ref                                                             title                                                    size  lastUpdated                 downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  -------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# ahmeduzaki/global-earthquake-tsunami-risk-assessment-dataset    Global Earthquake-Tsunami Risk Assessment Dataset       16151  2025-10-01 16:35:53.273000          18355        624  1.0
# jaderz/hospital-beds-management                                 Hospital Beds Management                                47583  2025-10-03 09:21:58.590000          15472        361  1.0
# ahmadrazakashif/bmw-worldwide-sales-records-20102024            BMW Worldwide Sales Records (2010–2024)                853348  2025-09-20 14:39:45.280000          20494        399  1.0
# ...

# %% [markdown]
# Install Dataset

# %%
# !kaggle datasets download -d robikscube/rollercoaster-database -p /content
# Out:
# Dataset URL: https://www.kaggle.com/datasets/robikscube/rollercoaster-database
# License(s): CC0-1.0
# ...
#   0% 0.00/984k [00:00<?, ?B/s]
# 100% 984k/984k [00:00<00:00, 1.12GB/s]

# %% [markdown]
# Unzip

# %%
# !unzip /content/rollercoaster-database.zip -d /content/rollercoaster-database
# Out:
# Archive:  /content/rollercoaster-database.zip
#   inflating: /content/rollercoaster-database/coaster_db.csv
#   inflating: /content/rollercoaster-database/flipflap.jpg

# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
pd.set_option('display.max_columns',200)

# %%
df = pd.read_csv('/content/rollercoaster-database/coaster_db.csv')

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [markdown]
# To remove a column

# %%
# df.drop(['Opening date'], axis = 1)

# %%
df = df[['coaster_name',
    # 'Length', 'Speed',
    'Location', 'Status',
    # 'Opening date',
      #  'Type',
    'Manufacturer',
    # 'Height restriction', 'Model', 'Height',
    #  'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
      #  'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
      #  'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
      #  'Track layout', 'Fastrack available', 'Soft opening date.1',
      #  'Closing date', 'Opened', 'Replaced by', 'Website',
      #  'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
      #  'Single rider line available', 'Restraint Style',
      #  'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
        'year_introduced',
     'latitude', 'longitude', 'Type_Main',
       'opening_date_clean',
    # 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
        'speed_mph',
    #  'height_value', 'height_unit',
    'height_ft', 'Inversions_clean', 'Gforce_clean']].copy()

# %%
df.dtypes
# Out:
# coaster_name           object
# Location               object
# Status                 object
# Manufacturer           object
# year_introduced         int64
# latitude              float64
# longitude             float64
# Type_Main              object
# opening_date_clean     object
# speed_mph             float64
# height_ft             float64
# Inversions_clean        int64
# Gforce_clean          float64
# dtype: object

# %% [markdown]
# Change a column dtype

# %%
df['opening_date_clean'] = pd.to_datetime(df['opening_date_clean'])

# %% [markdown]
# Rename Our columns

# %%
df = df.rename(columns={
    'coaster_name': 'Coaster Name',
    'year_introduced': 'Year Introduced',
    'opening_date_clean': 'Opening Date',
    'speed_mph': 'Speed_mph',
    'height_ft': 'Height_ft',
    'Inversions_clean': 'Inversions',
    'Gforce_clean': 'Gforce_clean'
})

# %%
df.head()
# Out:
#                              Coaster Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  Year Introduced  latitude  longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   Type_Main Opening Date  Speed_mph  Height_ft  Inversions  Gforce_clean
# ...

# %% [markdown]
# To see Null values

# %%
df.isna()
# Out:
#       Coaster Name  Location  Status  Manufacturer  Year Introduced  latitude  \
# 0            False     False   False         False            False     False
# 1            False     False   False         False            False     False
# 2            False     False   False          True            False     False
# 3            False     False   False         False            False     False
# 4            False     False   False         False            False     False
# ...            ...       ...     ...           ...              ...       ...
# 1082         False     False    True         False            False      True
# 1083         False     False   False         False            False     False
# 1084         False     False    True         False            False      True
# 1085         False     False   False         False            False      True
# 1086         False     False   False         False            False      True
#
# ...

# %%
df.isna().sum()
# Out:
# Coaster Name         0
# Location             0
# Status             213
# Manufacturer        59
# Year Introduced      0
# latitude           275
# longitude          275
# Type_Main            0
# Opening Date       250
# Speed_mph          150
# Height_ft          916
# Inversions           0
# Gforce_clean       725
# dtype: int64

# %% [markdown]
# To see Duplicated Columns and Rows

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082    False
# 1083    False
# 1084    False
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster Name, Location, Status, Manufacturer, Year Introduced, latitude, longitude, Type_Main, Opening Date, Speed_mph, Height_ft, Inversions, Gforce_clean]
# Index: []

# %%
df.duplicated(subset=['Coaster Name'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082     True
# 1083    False
# 1084     True
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
df.loc[df.duplicated(subset=['Coaster Name'])].head()
# Out:
#                           Coaster Name             Location     Status  \
# 43               Crystal Beach Cyclone   Crystal Beach Park    Removed
# 60                         Derby Racer         Revere Beach    Removed
# 61         Blue Streak (Conneaut Lake)   Conneaut Lake Park     Closed
# 167      Big Thunder Mountain Railroad                Other        NaN
# 237  Thunder Run (Canada's Wonderland)  Canada's Wonderland  Operating
#
#                                           Manufacturer  Year Introduced  \
# 43                                  Traver Engineering             1927
# 60                                      Fred W. Pearce             1937
# 61                                                 NaN             1938
# 167  Arrow Development (California and Florida)Dyna...             1980
# 237                                         Mack Rides             1986
#
#      latitude  longitude Type_Main Opening Date  Speed_mph  Height_ft  \
# ...

# %%
df.query('`Coaster Name` == "Crystal Beach Cyclone"')
# Out:
#              Coaster Name            Location   Status        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
#
#     Year Introduced  latitude  longitude Type_Main Opening Date  Speed_mph  \
# 39             1926   42.8617   -79.0598      Wood   1926-01-01       60.0
# 43             1927   42.8617   -79.0598      Wood   1926-01-01       60.0
#
#     Height_ft  Inversions  Gforce_clean
# 39        NaN           0           4.0
# 43        NaN           0           4.0

# %%
df.columns
# Out:
# Index(['Coaster Name', 'Location', 'Status', 'Manufacturer', 'Year Introduced',
#        'latitude', 'longitude', 'Type_Main', 'Opening Date', 'Speed_mph',
#        'Height_ft', 'Inversions', 'Gforce_clean'],
#       dtype='object')

# %% [markdown]
# Removing the Duplicates from subset of dataframe

# %%
df = df.loc[~df.duplicated(subset=['Coaster Name','Location','Opening Date'])] \
 .reset_index(drop=True).copy()

# %%
df.shape
# Out:
# (990, 13)

# %% [markdown]
# #Feature Understading

# %% [markdown]
# This Gives the values according to Most to Least Occuring, Tell How many times the data occur. for example in 1999 there were 46 rolercoasters which is most.

# %%
ax = df['Year Introduced'].value_counts() \
.head(10) \
.plot(kind='bar', title = 'Top year Introduced') \

ax.set_xlabel('Year Introduced')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Get idea of distribution of single column

# %%
df.columns
# Out:
# Index(['Coaster Name', 'Location', 'Status', 'Manufacturer', 'Year Introduced',
#        'latitude', 'longitude', 'Type_Main', 'Opening Date', 'Speed_mph',
#        'Height_ft', 'Inversions', 'Gforce_clean'],
#       dtype='object')

# %%
ax = df['Speed_mph'].plot(kind='hist',bins=20,title='Coasters Speed (mph)')
ax.set_xlabel('Speed (mph)')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# KDE -- Kernel Density Plot

# %%
ax = df['Speed_mph'].plot(kind='kde',title='Coasters Speed (mph)')
ax.set_xlabel('Speed (mph)')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# #Features Relationship

# %%
df.plot(kind='scatter',x='Speed_mph',y='Height_ft',title='Speed vs Height')
plt.plot()
# Out:
# []

# %%
df
# Out:
#                                Coaster Name                        Location  \
# 0                        Switchback Railway                    Coney Island
# 1                         Flip Flap Railway                   Sea Lion Park
# 2    Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3              Loop the Loop (Coney Island)                           Other
# 4              Loop the Loop (Young's Pier)                           Other
# ..                                      ...                             ...
# 985            Ice Breaker (roller coaster)                SeaWorld Orlando
# 986                   Leviathan (Sea World)                       Sea World
# 987               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 988                                 Tumbili                  Kings Dominion
# 989          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %% [markdown]
# Comaparing Two feature with seaborn

# %%
sns.scatterplot(x='Speed_mph',y='Height_ft', hue='Year Introduced', data=df)
# Out:
# <Axes: xlabel='Speed_mph', ylabel='Height_ft'>

# %% [markdown]
# Comparing More than Two Features with seaborn

# %%
sns.pairplot(df, vars=['Year Introduced','Speed_mph','Height_ft','Inversions','Gforce_clean'], hue='Type_Main')
plt.show()

# %%
df_corr = df[['Year Introduced','Speed_mph','Height_ft','Inversions','Gforce_clean']].dropna().corr()
df_corr
# Out:
#                  Year Introduced  Speed_mph  Height_ft  Inversions  \
# Year Introduced         1.000000   0.171978   0.135413   -0.209887
# Speed_mph               0.171978   1.000000   0.733999   -0.028705
# Height_ft               0.135413   0.733999   1.000000   -0.079736
# Inversions             -0.209887  -0.028705  -0.079736    1.000000
# Gforce_clean            0.160247   0.607383   0.466482    0.275991
#
#                  Gforce_clean
# Year Introduced      0.160247
# Speed_mph            0.607383
# Height_ft            0.466482
# Inversions           0.275991
# Gforce_clean         1.000000

# %%
sns.heatmap(df_corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #Asking a Question about the data Set

# %% [markdown]
# What are the locations with the faster Roller coasters(minimum of 10)?

# %%
ax = df.query('Location != "Other"') \
.groupby('Location')['Speed_mph'] \
.agg(['mean','count']) \
.query('count >= 10') \
.sort_values('mean')['mean'] \
.plot(kind='barh', figsize=(12,5), title='Average coaster speed by location')

ax.set_xlabel('Average coaster Speed')
[plt.show()]
# Out:
# [None]
